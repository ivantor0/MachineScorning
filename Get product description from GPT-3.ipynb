# %% [markdown]
# <a href="https://colab.research.google.com/github/isikus/MachineScorning/blob/main/Get%20product%20description%20from%20GPT-3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Code for getting products description from pretrained GPT-3

# %% [markdown]
# ## Install enviroment

# %% [markdown]
# Checking GPU card – the command below should work and show around 12-15k of available RAM

# %%
# !nvidia-smi
# Out:
# Wed Dec  9 14:54:34 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.45.01    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8     9W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip3 install -q urllib3==1.25.4 transformers==2.8.0

# !echo "Installed dependencies"
# Out:
#      |████████████████████████████████| 133kB 9.0MB/s
#      |████████████████████████████████| 573kB 11.9MB/s
#      |████████████████████████████████| 3.7MB 13.9MB/s
#      |████████████████████████████████| 890kB 45.8MB/s
#      |████████████████████████████████| 1.1MB 55.0MB/s
#      |████████████████████████████████| 133kB 57.8MB/s
#      |████████████████████████████████| 71kB 10.2MB/s
#      |████████████████████████████████| 7.0MB 55.0MB/s
# ...
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# Installed dependencies

# %%
# !wget -q --show-progress https://raw.githubusercontent.com/sberbank-ai/ru-gpts/master/generate_transformers.py

# !echo "Downloaded execution script"
# Out:
# generate_transforme 100%[===================>]  10.23K  --.-KB/s    in 0s
# Downloaded execution script

# %%
# !wget -q --show-progress https://storage.googleapis.com/ml-bucket-isikus/machine-scorning/products_desc.tar.gz
# !mkdir desc_model
# !tar -xzf products_desc.tar.gz -C desc_model

# !echo "Downloaded and extracted model files"
# Out:
# products_desc.tar.g 100%[===================>] 443.71M   238MB/s    in 1.9s
# Downloaded and extracted model files

# %% [markdown]
# ## Get responses from the model
#
# Don't forget to wrap the context into separators to show the model where the input part is, e. g. `<s>Товар: *ваш_товар*\n`
#
# You can also play around with parameters like `k`, `top_n` or `p`.

# %%
# !python generate_transformers.py \
    --model_type=gpt2 \
    --model_name_or_path=desc_model \
    --k=5 \
    --p=0.95 \
    --length=500
# Out:
# 2020-12-09 14:57:48.563651: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 12/09/2020 14:57:50 - INFO - transformers.tokenization_utils -   Model name 'desc_model' not found in model shortcut name list (gpt2, gpt2-medium, gpt2-large, gpt2-xl, distilgpt2). Assuming 'desc_model' is a path, a model identifier, or url to a directory containing tokenizer files.
# 12/09/2020 14:57:50 - INFO - transformers.tokenization_utils -   Didn't find file desc_model/added_tokens.json. We won't load it.
# 12/09/2020 14:57:50 - INFO - transformers.tokenization_utils -   loading file desc_model/vocab.json
# 12/09/2020 14:57:50 - INFO - transformers.tokenization_utils -   loading file desc_model/merges.txt
# 12/09/2020 14:57:50 - INFO - transformers.tokenization_utils -   loading file None
# 12/09/2020 14:57:50 - INFO - transformers.tokenization_utils -   loading file desc_model/special_tokens_map.json
# ...
