# %% [markdown]
# <a href="https://colab.research.google.com/github/isikus/MachineScorning/blob/main/NeuroKiSH%20on%20ruGPT3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NeuroKiSH on ruGPT3

# %% [markdown]
# ## Install enviroment

# %% [markdown]
# Checking GPU card – the command below should work and show around 12-15k of available RAM

# %%
# !nvidia-smi
# Out:
# Mon Dec 21 05:51:10 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.45.01    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   65C    P8    11W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip3 install -q urllib3==1.25.4 transformers==2.8.0

# !echo "Installed dependencies"
# Out:
#      |████████████████████████████████| 133kB 17.7MB/s
#      |████████████████████████████████| 573kB 28.6MB/s
#      |████████████████████████████████| 890kB 50.6MB/s
#      |████████████████████████████████| 3.7MB 49.1MB/s
#      |████████████████████████████████| 1.1MB 53.9MB/s
#      |████████████████████████████████| 133kB 59.2MB/s
#      |████████████████████████████████| 71kB 11.1MB/s
#      |████████████████████████████████| 7.1MB 44.8MB/s
# ...
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# Installed dependencies

# %%
# !wget -q --show-progress https://raw.githubusercontent.com/sberbank-ai/ru-gpts/master/generate_transformers.py

# !echo "Downloaded execution script"
# Out:
# generate_transforme 100%[===================>]  10.23K  --.-KB/s    in 0s
# Downloaded execution script

# %%
# !wget -q --show-progress https://storage.googleapis.com/ml-bucket-isikus/machine-scorning/kishverses.tar.gz
# !mkdir kish_model
# !tar -xzf kishverses.tar.gz -C kish_model

# !echo "Downloaded and extracted model files"
# Out:
# kishverses.tar.gz   100%[===================>] 443.64M  57.7MB/s    in 7.8s
# Downloaded and extracted model files

# %% [markdown]
# ## Get responses from the model
#
# Don't forget to wrap the context into separators to show the model where the input part is, e. g. `<s>Начало: *начало песни*\n`
#
# You can also play around with parameters like `k`, `top_n`, `temperature` or `p`.

# %%
# !python generate_transformers.py \
    --model_type=gpt2 \
    --model_name_or_path=kish_model \
    --k=5 \
    --p=0.95 \
    --length=500
# Out:
# 2020-12-21 07:22:43.821287: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 12/21/2020 07:22:45 - INFO - transformers.tokenization_utils -   Model name 'kish_model' not found in model shortcut name list (gpt2, gpt2-medium, gpt2-large, gpt2-xl, distilgpt2). Assuming 'kish_model' is a path, a model identifier, or url to a directory containing tokenizer files.
# 12/21/2020 07:22:45 - INFO - transformers.tokenization_utils -   Didn't find file kish_model/added_tokens.json. We won't load it.
# 12/21/2020 07:22:45 - INFO - transformers.tokenization_utils -   loading file kish_model/vocab.json
# 12/21/2020 07:22:45 - INFO - transformers.tokenization_utils -   loading file kish_model/merges.txt
# 12/21/2020 07:22:45 - INFO - transformers.tokenization_utils -   loading file None
# 12/21/2020 07:22:45 - INFO - transformers.tokenization_utils -   loading file kish_model/special_tokens_map.json
# ...
