# %% [markdown]
# <a href="https://colab.research.google.com/github/isikus/MachineScorning/blob/main/Get%20instructions%20from%20GPT-3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Code for getting instructions from pretrained GPT-3

# %% [markdown]
# ## Install enviroment

# %% [markdown]
# Checking GPU card – the command below should work and show around 12-15k of available RAM

# %%
# !nvidia-smi
# Out:
# Wed Dec  9 15:24:13 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.45.01    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P8     9W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip3 install -q urllib3==1.25.4 transformers==2.8.0

# !echo "Installed dependencies"
# Out:
#      |████████████████████████████████| 133kB 8.3MB/s
#      |████████████████████████████████| 573kB 14.5MB/s
#      |████████████████████████████████| 890kB 16.1MB/s
#      |████████████████████████████████| 3.7MB 17.8MB/s
#      |████████████████████████████████| 1.1MB 46.0MB/s
#      |████████████████████████████████| 133kB 59.1MB/s
#      |████████████████████████████████| 71kB 10.7MB/s
#      |████████████████████████████████| 7.0MB 52.4MB/s
# ...
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# Installed dependencies

# %%
# !wget -q --show-progress https://raw.githubusercontent.com/sberbank-ai/ru-gpts/master/generate_transformers.py

# !echo "Downloaded execution script"
# Out:
# generate_transforme 100%[===================>]  10.23K  --.-KB/s    in 0s
# Downloaded execution script

# %%
# !wget -q --show-progress https://storage.googleapis.com/ml-bucket-isikus/machine-scorning/wikihowto.tar.gz
# !mkdir wh_model
# !tar -xzf wikihowto.tar.gz -C wh_model

# !echo "Downloaded and extracted model files"
# Out:
# wikihowto.tar.gz    100%[===================>] 443.71M  57.5MB/s    in 8.7s
# Downloaded and extracted model files

# %% [markdown]
# ## Get responses from the model
#
# Don't forget to wrap the context into separators to show the model where the input part is, e. g. `<s> Вопрос: *ваш_вопрос*\n`
#
# You can also play around with parameters like `k`, `top_n` or `p`.

# %%
# !python generate_transformers.py \
    --model_type=gpt2 \
    --model_name_or_path=wh_model \
    --k=5 \
    --p=0.95 \
    --length=500
# Out:
# 2020-12-08 22:20:20.672891: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 12/08/2020 22:20:24 - INFO - transformers.tokenization_utils -   Model name 'essays_model' not found in model shortcut name list (gpt2, gpt2-medium, gpt2-large, gpt2-xl, distilgpt2). Assuming 'essays_model' is a path, a model identifier, or url to a directory containing tokenizer files.
# 12/08/2020 22:20:24 - INFO - transformers.tokenization_utils -   Didn't find file essays_model/added_tokens.json. We won't load it.
# 12/08/2020 22:20:24 - INFO - transformers.tokenization_utils -   loading file essays_model/vocab.json
# 12/08/2020 22:20:24 - INFO - transformers.tokenization_utils -   loading file essays_model/merges.txt
# 12/08/2020 22:20:24 - INFO - transformers.tokenization_utils -   loading file None
# 12/08/2020 22:20:24 - INFO - transformers.tokenization_utils -   loading file essays_model/special_tokens_map.json
# ...
